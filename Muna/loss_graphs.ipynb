# %%
"""
https://github.com/comp0030-photoToSketch/sketch-rnn/blob/7df3c450a94a23e6ae496d60693c5bc22f7ce0e1/Src/photo_to_sketch.ipynb

- taken directly from these loss outputs to avoid retraining
"""
import matplotlib.pyplot as plt
data = [2.6487, 1.1476, 0.9197, 0.6995, 0.7080, 0.5986, 0.5960, 0.5435, 0.5003, 0.5234, 0.5303, 0.5765, 0.4783] 
plt.plot(data)
plt.title('Loss of Sketch-to-Sketch Cat model')
plt.xlabel('Epochs * 100')
plt.ylabel('Loss = RL + KL + (EL * 2)')
# Out:
# Text(0, 0.5, 'Loss = RL + KL + (EL * 2)')
